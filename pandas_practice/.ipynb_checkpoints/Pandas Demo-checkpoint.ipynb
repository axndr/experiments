# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')

# %%
df.tail(10)
# Out:
#            MainBranch Hobbyist  Age Age1stCode CompFreq  CompTotal  \
# Respondent
# 64104             NaN      Yes  NaN         19      NaN        NaN
# 64236             NaN      Yes  NaN        NaN      NaN        NaN
# 64330             NaN      Yes  NaN          5      NaN        NaN
# 64480             NaN      Yes  NaN         21      NaN        NaN
# 64567             NaN      Yes  NaN        NaN      NaN        NaN
# 64858             NaN      Yes  NaN         16      NaN        NaN
# 64867             NaN      Yes  NaN        NaN      NaN        NaN
# 64898             NaN      Yes  NaN        NaN      NaN        NaN
# 64925             NaN      Yes  NaN        NaN      NaN        NaN
# 65112             NaN      Yes  NaN        NaN      NaN        NaN
#
#             ConvertedComp        Country CurrencyDesc CurrencySymbol  ...  \
# Respondent                                                            ...
# ...

# %%
df.shape
# Out:
# (64461, 60)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64461 entries, 1 to 65112
# Data columns (total 60 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   MainBranch                    64162 non-null  object
#  1   Hobbyist                      64416 non-null  object
#  2   Age                           45446 non-null  float64
#  3   Age1stCode                    57900 non-null  object
#  4   CompFreq                      40069 non-null  object
#  5   CompTotal                     34826 non-null  float64
#  6   ConvertedComp                 34756 non-null  float64
#  7   Country                       64072 non-null  object
#  8   CurrencyDesc                  45472 non-null  object
#  9   CurrencySymbol                45472 non-null  object
#  10  DatabaseDesireNextYear        44070 non-null  object
#  11  DatabaseWorkedWith            49537 non-null  object
# ...

# %%
pd.set_option('display.max_columns', 61)
pd.set_option('display.max_rows', 61)

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %%
schema_df
# Out:
#                           Column  \
# 0                     Respondent
# 1                     MainBranch
# 2                       Hobbyist
# 3                            Age
# 4                     Age1stCode
# 5                       CompFreq
# 6                      CompTotal
# 7                  ConvertedComp
# 8                        Country
# 9                   CurrencyDesc
# 10                CurrencySymbol
# 11        DatabaseDesireNextYear
# 12            DatabaseWorkedWith
# 13                       DevType
# 14                       EdLevel
# 15                    Employment
# 16                     Ethnicity
# 17                        Gender
# 18                    JobFactors
# 19                        JobSat
# 20                       JobSeek
# 21        LanguageDesireNextYear
# 22            LanguageWorkedWith
# 23        MiscTechDesireNextYear
# 24            MiscTechWorkedWith
# 25  NEWCollabToolsDesireNextYear
# 26      NEWCollabToolsWorkedWith
# ...

# %%
schema_df.head()
# Out:
#        Column                                       QuestionText
# 0  Respondent  Randomized respondent ID number (not in order ...
# 1  MainBranch  Which of the following options best describes ...
# 2    Hobbyist                            Do you code as a hobby?
# 3         Age  What is your age (in years)? If you prefer not...
# 4  Age1stCode  At what age did you write your first line of c...

# %%
contacts = {
    'Name': ['Alex', 'India', 'Eric'],
    'Last_Name': ['Clifford', 'Acklin', 'Clifford'],
    'PhoneNumber': [9014409678, 5645454654, 4984566544],
    'Address': ['Harbert', 'Washington', 'Eden'],
}

print(contacts['Name'])
# Out:
# ['Alex', 'India', 'Eric']

# %%
contacts_df = pd.DataFrame(contacts)
contacts_df
# Out:
#     Name Last_Name  PhoneNumber     Address
# 0   Alex  Clifford   9014409678     Harbert
# 1  India    Acklin   5645454654  Washington
# 2   Eric  Clifford   4984566544        Eden

# %%
contacts_name_series = contacts_df['Name']
contacts_name_series
# Out:
# 0     Alex
# 1    India
# 2     Eric
# Name: Name, dtype: object

# %%
contacts_df.Name
# Out:
# 0     Alex
# 1    India
# 2     Eric
# Name: Name, dtype: object

# %%
contacts_df[['Name', 'Address']]
# Out:
#     Name     Address
# 0   Alex     Harbert
# 1  India  Washington
# 2   Eric        Eden

# %%
contacts_df.loc[0:2, ['Name', 'Address']]
# Out:
#     Name     Address
# 0   Alex     Harbert
# 1  India  Washington
# 2   Eric        Eden

# %%
contacts_df.iloc[[2], [1]]
# Out:
#   Last_Name
# 2  Clifford

# %%
contacts_df[['Name', 'Address']].iloc[0]
# Out:
# Name          Alex
# Address    Harbert
# Name: 0, dtype: object

# %%
contacts_df.count()
# Out:
# Name           3
# Last_Name      3
# PhoneNumber    3
# Address        3
# dtype: int64

# %%
contacts_df
# Out:
#     Name Last_Name  PhoneNumber     Address
# 0   Alex  Clifford   9014409678     Harbert
# 1  India    Acklin   5645454654  Washington
# 2   Eric  Clifford   4984566544        Eden

# %%
contacts_df.loc[[0, 1], ['Name', 'PhoneNumber']]
# Out:
#     Name  PhoneNumber
# 0   Alex   9014409678
# 1  India   5645454654

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
df.shape
# Out:
# (64461, 60)

# %%
df.loc[1:5, 'Hobbyist':'Age1stCode']
# Out:
#            Hobbyist   Age Age1stCode
# Respondent
# 1               Yes   NaN         13
# 2                No   NaN         19
# 3               Yes   NaN         15
# 4               Yes  25.0         18
# 5               Yes  31.0         16

# %%
contacts_df.set_index('Name', inplace=True)

# %%
contacts_df.index
# Out:
# Index(['Alex', 'India', 'Eric'], dtype='object', name='Name')

# %%
contacts_df
# Out:
#       Last_Name  PhoneNumber     Address
# Name
# Alex   Clifford   9014409678     Harbert
# India    Acklin   5645454654  Washington
# Eric   Clifford   4984566544        Eden

# %%
contacts_df.loc['Alex', 'PhoneNumber']
# Out:
# 9014409678

# %%
contacts_df.reset_index(inplace=True)
contacts_df
# Out:
#     Name Last_Name  PhoneNumber     Address
# 0   Alex  Clifford   9014409678     Harbert
# 1  India    Acklin   5645454654  Washington
# 2   Eric  Clifford   4984566544        Eden

# %%
schema_df.
# Out:
#                           Column  \
# 0                     Respondent
# 1                     MainBranch
# 2                       Hobbyist
# 3                            Age
# 4                     Age1stCode
# 5                       CompFreq
# 6                      CompTotal
# 7                  ConvertedComp
# 8                        Country
# 9                   CurrencyDesc
# 10                CurrencySymbol
# 11        DatabaseDesireNextYear
# 12            DatabaseWorkedWith
# 13                       DevType
# 14                       EdLevel
# 15                    Employment
# 16                     Ethnicity
# 17                        Gender
# 18                    JobFactors
# 19                        JobSat
# 20                       JobSeek
# 21        LanguageDesireNextYear
# 22            LanguageWorkedWith
# 23        MiscTechDesireNextYear
# 24            MiscTechWorkedWith
# 25  NEWCollabToolsDesireNextYear
# 26      NEWCollabToolsWorkedWith
# ...

# %%
filt = (contacts_df['Last_Name'] == 'Clifford')

# %%
contacts_df[~filt]
# Out:
#     Name Last_Name  PhoneNumber     Address
# 1  India    Acklin   5645454654  Washington

# %%
contacts_df.loc[~(contacts_df['Last_Name'] == 'Clifford'), 'PhoneNumber']
# SELECT phone_number FROM contacts WHERE last_name == "Clifford" AND name == 'Alex';
# Out:
# 1    5645454654
# Name: PhoneNumber, dtype: int64
